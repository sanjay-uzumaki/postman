# %%
import sys
import subprocess
command = "newman run flickr1"
command = subprocess.Popen(command.split(' '), stdout=subprocess.PIPE, stderr=subprocess.STDOUT,shell=True)
output, error = command.communicate()

# %%
output
# Out:
# b'newman\n\nNew Collection\n\n\xe2\x86\x92 New Request\n  GET https://www.flickr.com/services/rest/?method=flickr.photos.getPopular&api_key=253a57a55cd23746c99ea55e495494c8&user_id=193141403%40N03&format=json&nojsoncallback=1 [200 OK, 759B, 834ms]\n\n\xe
# ...

# %%
print(str(output, "utf-8"))
z=str(output, "utf-8")
# Out:
# newman
#
# New Collection
#
# → New Request
#   GET https://www.flickr.com/services/rest/?method=flickr.photos.getPopular&api_key=253a57a55cd23746c99ea55e495494c8&user_id=193141403%40N03&format=json&nojsoncallback=1 [200 OK, 759B, 834ms]
#
# ┌─────────────────────────┬────────────────────┬───────────────────┐
# │                         │           executed │            failed │
# ├─────────────────────────┼────────────────────┼───────────────────┤
# │              iterations │                  1 │                 0 │
# ├─────────────────────────┼────────────────────┼───────────────────┤
# │                requests │                  1 │                 0 │
# ├─────────────────────────┼────────────────────┼───────────────────┤
# │            test-scripts │                  0 │                 0 │
# ├─────────────────────────┼────────────────────┼───────────────────┤
# │      prerequest-scripts │                  0 │                 0 │
# ...

# %%
if int(z[641])>0:
    print("FAIL")
else:
    print("PASS");
# Out:
# PASS

# %%
# Out:
# '0'
